# %%
import pandas as pd
menu = {
    "SR":[1,2,3] ,
    "NAME":["ALOO TIKKI","MAHARAJA","MAC SPECIAL"],
    "PRICE":['5$','10$','15$']}

# %%
print( pd.DataFrame(menu))
# Out:
#    SR         NAME PRICE
# 0   1   ALOO TIKKI    5$
# 1   2     MAHARAJA   10$
# 2   3  MAC SPECIAL   15$

# %%
# Input: Choose a burger
burger = int(input("Choose a burger?"))
if burger == 1:
    # Input: Quantity
    quantity = int(input("How many quantity do you want? "))
    
    # Input: Check if the user is a student
    student = input("Are you a student? (yes/no): ").strip().lower()
    
    # Calculate initial price
    price = quantity * burger_price

    # Initialize variables
    student_discount = 0
    delivery_charge = 0
    tip = 0

    # Apply student discount if applicable
    if student == "yes":
        student_discount = 0.20 * price  # 20% discount
        print(f"Student Discount: -{student_discount}$")
    else:
        print("No student discount applied.")

    # Input: Delivery option
    delivery = input("Do you want delivery? (yes/no): ").strip().lower()
    if delivery == "yes":
        delivery_charge = 0.05 * (price - student_discount)  # 5% on discounted price
        print(f"Delivery Charge: +{delivery_charge}$")
    else:
        print("No delivery charge applied.")

    # Input: Tip
    tip_option = input("Do you want to give a tip? (2$, 5$, 10$ or no): ").strip().lower()
    if tip_option in ['2', '5', '10']:
        tip = int(tip_option)
        print(f"Tip: +{tip}$")
    else:
        print("No tip given.")

    # Calculate final total
    total_cost = price - student_discount + delivery_charge + tip

    # Print the final total cost
    print("\n*************** Final Bill ****************")
    print(f"Your order is: Aloo Tikki")
    print(f"Quantity: {quantity}")
    print(f"Subtotal: {price}$")
    
    if student_discount > 0:
        print(f"Student Discount: -{student_discount}$")
    if delivery_charge > 0:
        print(f"Delivery Charge: +{delivery_charge}$")
    if tip > 0:
        print(f"Tip: +{tip}$")
    
    print(f"Total Cost: {total_cost}$")
    print("Thank you and come again!")
elif burger == 2:
    # Input: Quantity
    quantity = int(input("How many quantity do you want? "))
    
    # Input: Check if the user is a student
    student = input("Are you a student? (yes/no): ").strip().lower()
    
    # Calculate initial price
    price = quantity * burger_price

    # Initialize variables
    student_discount = 0
    delivery_charge = 0
    tip = 0

    # Apply student discount if applicable
    if student == "yes":
        student_discount = 0.20 * price  # 20% discount
        print(f"Student Discount: -{student_discount}$")
    else:
        print("No student discount applied.")

    # Input: Delivery option
    delivery = input("Do you want delivery? (yes/no): ").strip().lower()
    if delivery == "yes":
        delivery_charge = 0.05 * (price - student_discount)  # 5% on discounted price
        print(f"Delivery Charge: +{delivery_charge}$")
    else:
        print("No delivery charge applied.")

    # Input: Tip
    tip_option = input("Do you want to give a tip? (2$, 5$, 10$ or no): ").strip().lower()
    if tip_option in ['2', '5', '10']:
        tip = int(tip_option)
        print(f"Tip: +{tip}$")
    else:
        print("No tip given.")

    # Calculate final total
    total_cost = price - student_discount + delivery_charge + tip

    # Print the final total cost
    print("\n*************** Final Bill ****************")
    print(f"Your order is:MAHARAJA ")
    print(f"Quantity: {quantity}")
    print(f"Subtotal: {price}$")
    
    if student_discount > 0:
        print(f"Student Discount: -{student_discount}$")
    if delivery_charge > 0:
        print(f"Delivery Charge: +{delivery_charge}$")
    if tip > 0:
        print(f"Tip: +{tip}$")
    
    print(f"Total Cost: {total_cost}$")
    print("Thank you and come again!")
elif burger == 3:
    # Input: Quantity
    quantity = int(input("How many quantity do you want? "))
    
    # Input: Check if the user is a student
    student = input("Are you a student? (yes/no): ").strip().lower()
    
    # Calculate initial price
    price = quantity * burger_price

    # Initialize variables
    student_discount = 0
    delivery_charge = 0
    tip = 0

    # Apply student discount if applicable
    if student == "yes":
        student_discount = 0.20 * price  # 20% discount
        print(f"Student Discount: -{student_discount}$")
    else:
        print("No student discount applied.")

    # Input: Delivery option
    delivery = input("Do you want delivery? (yes/no): ").strip().lower()
    if delivery == "yes":
        delivery_charge = 0.05 * (price - student_discount)  # 5% on discounted price
        print(f"Delivery Charge: +{delivery_charge}$")
    else:
        print("No delivery charge applied.")

    # Input: Tip
    tip_option = input("Do you want to give a tip? (2$, 5$, 10$ or no): ").strip().lower()
    if tip_option in ['2', '5', '10']:
        tip = int(tip_option)
        print(f"Tip: +{tip}$")
    else:
        print("No tip given.")

    # Calculate final total
    total_cost = price - student_discount + delivery_charge + tip

    # Print the final total cost
    print("\n*************** Final Bill ****************")
    print(f"Your order is: MAC SPECIAL")
    print(f"Quantity: {quantity}")
    print(f"Subtotal: {price}$")
    
    if student_discount > 0:
        print(f"Student Discount: -{student_discount}$")
    if delivery_charge > 0:
        print(f"Delivery Charge: +{delivery_charge}$")
    if tip > 0:
        print(f"Tip: +{tip}$")
    
    print(f"Total Cost: {total_cost}$")
    print("Thank you and come again!")

else:
    print("Invalid selection. Please choose a valid burger.")
# Out:
# Choose a burger? 3
# How many quantity do you want?  2
# Are you a student? (yes/no):  YES
# Student Discount: -2.0$
# Do you want delivery? (yes/no):  NO
# No delivery charge applied.
# Do you want to give a tip? (2$, 5$, 10$ or no):  5
# Tip: +5$
#
# *************** Final Bill ****************
# Your order is: MAC SPECIAL
# Quantity: 2
# Subtotal: 10$
# Student Discount: -2.0$
# Tip: +5$
# Total Cost: 13.0$
# Thank you and come again!
